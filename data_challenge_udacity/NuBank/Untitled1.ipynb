# %%
# importação do pandas para trabalhar com calcúlos no modelo
import numpy as np

# importação do pandas para realizar a analisse dos dados
import pandas as pd

# %%
# Fazer a leitura do dataset
data = pd.read_csv('acquisition_test.csv')

# %%
data.head(5)
# Out:
#                                     ids                   score_1  \
# 0  810e3277-619e-3154-7ba0-ebddfc5f7ea9  smzX0nxh5QlePvtVf6EAeg==
# 1  285ce334-3602-42b3-51cb-eebfcba48a09  4DLlLW62jReXaqbPaHp1vQ==
# 2  08efdf0f-f8f1-b968-3452-6b634eabf43f  DGCQep2AE5QRkNCshIAlFQ==
# 3  c81955ef-e3fe-e40e-b8b9-916dfea3b80d  DGCQep2AE5QRkNCshIAlFQ==
# 4  7f93590f-4a91-aec4-5062-cb1ba2c16a84  8k8UDR4Yx0qasAjkGrUZLw==
#
#                     score_2  score_3     score_4   score_5     score_6  \
# 0  tHpS8e9F8d9zg3iOQM9tsA==    710.0  104.174961  0.661509  123.015325
# 1  tQUTfUyeuGkhRotd+6WjVg==    120.0  100.434557  0.139784  120.134718
# 2  Fv28Bz0YRTVAT5kl1bAV6g==    280.0   95.399016  0.592517  101.661396
# 3  RO7MTL+j4PH2gNzbhNTq/A==    240.0  100.979281  0.588796  101.724127
# 4  wkeCdGeu5sEv4/fjwR0aDg==    430.0  101.287897  0.694936  114.951255
#
#    risk_rate  last_amount_borrowed  last_borrowed_in_months  \
# 0       0.43                   NaN                      NaN
# ...

# %%
print(data.shape)
# Out:
# (19592, 41)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19592 entries, 0 to 19591
# Data columns (total 41 columns):
# ids                                                 19592 non-null object
# score_1                                             19369 non-null object
# score_2                                             19369 non-null object
# score_3                                             19369 non-null float64
# score_4                                             19592 non-null float64
# score_5                                             19592 non-null float64
# score_6                                             19592 non-null float64
# risk_rate                                           19369 non-null float64
# last_amount_borrowed                                6599 non-null float64
# last_borrowed_in_months                             6599 non-null float64
# credit_limit                                        13639 non-null float64
# ...

# %%
data.describe()
# Out:
#             score_3       score_4       score_5       score_6     risk_rate  \
# count  19369.000000  19592.000000  19592.000000  19592.000000  19369.000000
# mean     348.143425     99.977364      0.497343     99.982892      0.295684
# std      109.226430      3.154230      0.289780     10.074832      0.100659
# min       20.000000     88.270607      0.000101     61.585973      0.020000
# 25%      270.000000     97.836702      0.246437     93.239757      0.220000
# 50%      340.000000     99.976199      0.493184     99.978768      0.290000
# 75%      420.000000    102.109535      0.749955    106.800689      0.360000
# max      860.000000    112.890040      0.999982    142.430069      0.760000
#
#        last_amount_borrowed  last_borrowed_in_months   credit_limit  \
# count           6599.000000              6599.000000   13639.000000
# mean           13877.997378                41.877254   34973.896987
# std             8079.566962                10.321246   38060.165852
# ...
